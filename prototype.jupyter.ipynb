# %%
from sqlalchemy import create_engine
# %pip install pandas
import pandas as pd 

# SQLAlchemy connectable
cnx = create_engine('postgresql://shubham:123456789@localhost/vehicle_listings').connect()
 
# table named 'employee' will be returned as a dataframe.
df = pd.read_sql_table('vehicle_listings', cnx)
print(df.head)

# %%
df.columns

# %%
new_df = df.query("make=='Ford' and model=='F-150' and year==2022")
new_df.head

# %%
map.pyplot.plot(new_df["listing_mileage"], new_df["listing_price"], marker='o', linestyle='', markersize=8, color='r', label='Scatter Plot')

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
x = np.array(new_df["listing_mileage"]).reshape(-1, 1)
y = np.reshape(new_df["listing_price"])
